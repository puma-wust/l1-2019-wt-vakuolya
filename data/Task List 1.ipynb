# %% [markdown]
# # 2018/2019 - Task List 1
#
# 1. Generate random variable from prefered dystribution using Pyro (pyro.sample)
#
#     - animate how distribution of values changes
#     - animate histograms of values
#     - start with empty list of values, generate new samples, generate histogram
#
#
# 2. Write a simulator (and exact solution utilizing Bayes theorem) for chances to be ill on a certain disease. We know that it affects from about 1 to 100 out of 50,000 people. There was developed a test to check whether the person has the disease and it is quite accurate: the probability that the test result is positive (suggesting the person has the disease), given that the person does not have the disease, is only 2 percent; the probability that the test result is negative (suggesting the person does not have the disease), given that the person has the disease, is only 1 percent. When a random person gets tested for the disease and the result comes back positive, what is the probability that the person has the disease? Check whole parameter space and visualise results.
#
#     - it must be a simulator!
#     - sample from distribution using given probabilities
#     - repeate experiment and compare with Bayes equation

# %% [markdown]
# ## Required imports

# %%
# %matplotlib inline
import pyro
import torch
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# %% [markdown]
# ## Generating single value from normal distribution with given mean and variance

# %%
mean = 0
variance = 10
x = pyro.sample("normal_sampling", pyro.distributions.Normal(mean, variance))
print(x)
# Out:
# tensor(-1.3181)

# %% [markdown]
# ## Sampling from categorical probabilities with given probabilities

# %%
x = pyro.sample("categorical_sampling", pyro.distributions.Categorical(logits = torch.tensor([0.5, 0.5])))
print(x)
# Out:
# tensor(1)

# %% [markdown]
# ## Animating data

# %%
def animate():
    # First set up the figure, the axis, and the plot element we want to animate
    fig, ax = plt.subplots()

    ax.set_xlim(( 0, 2))
    ax.set_ylim((-2, 2))

    line, = ax.plot([], [], lw=2)
    
    # animation function. This is called sequentially
    def sin(i):
        x = np.linspace(0, 2, 1000)
        y = np.sin(2 * np.pi * (x - 0.01 * i))
        line.set_data(x, y)
        return (line,)

    # initialization function: plot the background of each frame
    def init():
        line.set_data([], [])
        return (line,)
    # call the animator. blit=True means only re-draw the parts that have changed.
    anim = animation.FuncAnimation(fig, sin, init_func=init,
                                   frames=100, interval=20, blit=True)
    return HTML(anim.to_jshtml())

animate()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img4afad71ec5b34317bf24ddbddfaf04b9">
#     <br>
#     <input id="_anim_slider4afad71ec5b34317bf24ddbddfaf04b9" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim4afad71ec5b34317bf24ddbddfaf04b9.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim4afad71ec5b34317bf24ddbddfaf04b9.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select4afad71ec5b34317bf24ddbddfaf04b9" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4afad71ec5b34317bf24ddbddfaf04b9";
#     var slider_id = "_anim_slider4afad71ec5b34317bf24ddbddfaf04b9";
#     var loop_select_id = "_anim_loop_select4afad71ec5b34317bf24ddbddfaf04b9";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAIABJREFUeJzt3Xlc1HX+B/DXDCMgp4CgwKAcg9yH\
# Oh6ZmRfikZjHetSWpYaWrdXu9qs9aqvNctvN7bBsWSvt0rIL8z7SDlNxxBM8UEBu5BAQ5BhmPr8/\
# RiddUEBhvvOF1/Px8PGQme/M98Uw833P5/h+vgohhAAREZHMKKUOQEREdCtYwIiISJZYwIiISJZY\
# wIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiI\
# SJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZY\
# wIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJZYwIiISJYkL2C5ubkYNWoU\
# wsLCEBERgTfffLPJNkIILFmyBBqNBtHR0UhNTZUgKRERWROV5AFUKrz++usYMGAALl26hIEDByIu\
# Lg7h4eHmbbZs2YKMjAxkZGTgwIEDePTRR3HgwAEJUxMRkdQkb4F5e3tjwIABAABnZ2eEhYUhPz//\
# um2Sk5Px4IMPQqFQYOjQoaioqEBhYaEUcYmIyEpIXsCulZ2djcOHD2PIkCHX3Z6fnw8/Pz/zz2q1\
# ukmRIyKirkXyLsSrqqurMX36dLzxxhtwcXG57j4hRJPtFQpFk9uSkpKQlJQEADh16hRCQ0M7JiwR\
# USeVnZ2N0tJSqWO0ilUUML1ej+nTp+P+++/HtGnTmtyvVquRm5tr/jkvLw8+Pj5NtktMTERiYiIA\
# QKvVQqfTdVxoIqJOSKvVSh2h1STvQhRCYP78+QgLC8Pvf//7ZrdJSEjARx99BCEE9u/fD1dXV3h7\
# e1s4KRERWRPJW2B79+7Fxx9/jKioKMTGxgIAXnnlFeTk5AAAFi1ahIkTJ2Lz5s3QaDRwcHDAhx9+\
# KGVkIiKyApIXsOHDhzc7xnUthUKBd955x0KJiIhIDiTvQiQiIroVLGBERCRLLGBERCRLLGBERCRL\
# LGBERCRLLGBERCRLLGBERCRLLGBERCRLLGBERCRLLGBERCRLLGBERCRLLGBERCRLLGBERCRLLGBE\
# RCRLLGBERCRLLGBERCRLLGBERCRLLGBERCRLkhewefPmwcvLC5GRkc3ev2fPHri6uiI2NhaxsbF4\
# 6aWXLJyQiIiskUrqAA899BAef/xxPPjggzfc5q677sLGjRstmIqIiKyd5C2wESNGwN3dXeoYREQk\
# M5IXsNbYt28fYmJiMGHCBKSlpUkdh4iIrIDkXYgtGTBgAM6fPw8nJyds3rwZ9957LzIyMprdNikp\
# CUlJSQCAkpISS8YkIiILs/oWmIuLC5ycnAAAEydOhF6vR2lpabPbJiYmQqfTQafTwdPT05IxiYjI\
# wqy+gBUVFUEIAQBISUmB0WiEh4eHxKmIiEhqknchzpkzB3v27EFpaSnUajVefPFF6PV6AMCiRYvw\
# 5ZdfYuXKlVCpVOjevTvWrVsHhUIhcWoiIpKaQlxt3nQyWq0WOp1O6hhERLIip2On1XchEhERNYcF\
# jIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiI\
# ZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZIkFjIiIZEnyAjZv3jx4eXkhMjKy\
# 2fuFEFiyZAk0Gg2io6ORmppq4YRERGSNJC9gDz30ELZu3XrD+7ds2YKMjAxkZGQgKSkJjz76qAXT\
# ERGRtZK8gI0YMQLu7u43vD85ORkPPvggFAoFhg4dioqKChQWFlowYccwGgUqa/W

# %% [markdown]
# ## Drawing histogram

# %%
x = np.random.normal(size = 1000)
plt.hist(x, density=True, bins=30)
plt.ylabel('Probability');

# %% [markdown]
# ## Task 1

# %%
## Insert solution here
def animate():
    fig, ax = plt.subplots()
    values = []
    
    def func(fr):
        ax.clear()
        values.append(pyro.sample("normal_distr", pyro.distributions.Normal(0, 1)))
        ax.hist(values, density=True, bins=50)

    anim = animation.FuncAnimation(fig, func, frames=100, interval=10)
    return HTML(anim.to_jshtml())

animate()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imge21f12b231a54dbd91653a1099c919a0">
#     <br>
#     <input id="_anim_slidere21f12b231a54dbd91653a1099c919a0" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anime21f12b231a54dbd91653a1099c919a0.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anime21f12b231a54dbd91653a1099c919a0.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecte21f12b231a54dbd91653a1099c919a0" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge21f12b231a54dbd91653a1099c919a0";
#     var slider_id = "_anim_slidere21f12b231a54dbd91653a1099c919a0";
#     var loop_select_id = "_anim_loop_selecte21f12b231a54dbd91653a1099c919a0";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAFDtJREFUeJzt3H9sVfX9x/HXpd1qDLDKaJsL3VYK\
# jfYH7R1cLMsqK3R3/kKI0iFotsva0IU021J/IMlmZIlKl8VFF1jwbmQ2Lusy2WxJ1GaWiktISLlZ\
# LwkDR8Ngod21XGxxSBDb8vn+sdgvjPLlsq/cc974fPx1ezhXX7lqn97T0xtwzjkBAGDMFK8HAADw\
# 3yBgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEA\
# TCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEA\
# TCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJOyvR5wvcycOVNFRUVe\
# zwAAU44fP65Tp055PSMtN2zAioqKFI/HvZ4BAKaEw2GvJ6TNV5cQP/zwQ91+++2qqqpSeXm5nnrq\
# KUnSunXrNGfOHIVCIYVCISUSCY+XAgC85qt3YDk5Oerp6dHUqVM1Ojqqmpoa3X333ZKkn/70p6qv\
# r/d4IQDAL3z1DiwQCGjq1KmSpNHRUY2OjioQCHi8CgDgR74KmCSNj48rFAopPz9fkUhE1dXVkqQf\
# /vCHqqysVEtLi86fP+/xSgCA13wXsKysLCUSCQ0MDKi3t1cHDx7Uli1b9M4772j//v0aHh7WT37y\
# k0mfG4vFFA6HFQ6HlUqlMrwcAJBJvgvYx3Jzc1VbW6uuri4Fg0EFAgHl5OToO9/5jnp7eyd9TlNT\
# k+LxuOLxuPLy8jK8GACQSb4KWCqV0unTpyVJ586dU3d3t2677TYlk0lJknNOHR0dqqio8HImAMAH\
# fHUXYjKZVDQa1fj4uC5cuKDVq1dr+fLlWrZsmVKplJxzCoVC2r59u9dTAQAe81XAKisr1dfXd9nx\
# np6ejO4o2vTapMePt96b0R0AcCVX+j4lfXq+V/nqEiIAAOkiYAAAkwgYAMAkAgYAMImAAQBMImAA\
# AJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAA\
# AJMIGADAJAIGADCJgAEATPJVwD788EPdfvvtqqqqUnl5uZ566ilJ0rFjx1RdXa2SkhI9+OCD+uij\
# jzxeCgDwmq8ClpOTo56eHh04cECJREJdXV3at2+fnnjiCbW0tKi/v1+33HKLduzY4fVUAIDHfBWw\
# QCCgqVOnSpJGR0c1OjqqQCCgnp4e1dfXS5Ki0ag6Ojq8nAkA8AFfBUySxsfHFQqFlJ+fr0gkorlz\
# 5yo3N1fZ2dmSpMLCQg0ODnq8EgDgNd8FLCsrS4lEQgMDA+rt7dXhw4cvOycQCEz63FgspnA4rHA4\
# rFQqdb2nAgA85LuAfSw3N1e1tbXat2+fTp8+rbGxMUnSwMCAZs2aNelzmpqaFI/HFY/HlZeXl8m5\
# AIAM81XAUqmUTp8+LUk6d+6curu7VVpaqqVLl2rnzp2SpLa2Nq1cudLLmQAAH8j2esDFksmkotGo\
# xsfHdeHCBa1evVrLly9XWVmZ1qxZox/96Ef68pe/rMbGRq+nAgA85quAVVZWqq+v77LjxcXF6u3t\
# 9WARAMCvfHUJEQCAdBEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkE\
# DABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAm+SpgJ06c\
# 0NKlS1VaWqry8nK98MILkqTNmzdr9uzZCoVCCoVCev311z1eCgDwWrbXAy6WnZ2

# %% [markdown]
# ## Task 2

# %%
## Insert solution here
